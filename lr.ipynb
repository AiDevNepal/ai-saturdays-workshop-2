# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import pandas as pd 
# %matplotlib inline

# %%
X = np.linspace(-1, 1,101)
noise = np.random.randn(X.shape[0])*0.33
plt.plot(noise)

# %%
Y = 2*X+noise #y = mx+c

# %%
plt.plot(X)

# %%
plt.plot(Y)

# %%
model = LinearRegression()
X=X.reshape(-1,1)
Y=Y.reshape(-1,1)

model.fit(X,Y)   #training
m, c = model.coef_, model.intercept_
print(m, c)

plt.plot(X, Y)  #input traing dataset
plt.plot(X, m * X + c, 'r')   #y=mx+c
# Out:
# [[1.90245285]] [0.02409126]

# %%
mode
# Out:
# array([[-1.  ],
#        [-0.98],
#        [-0.96],
#        [-0.94],
#        [-0.92],
#        [-0.9 ],
#        [-0.88],
#        [-0.86],
#        [-0.84],
#        [-0.82],
#        [-0.8 ],
#        [-0.78],
#        [-0.76],
#        [-0.74],
#        [-0.72],
#        [-0.7 ],
#        [-0.68],
#        [-0.66],
#        [-0.64],
#        [-0.62],
#        [-0.6 ],
#        [-0.58],
#        [-0.56],
#        [-0.54],
#        [-0.52],
#        [-0.5 ],
#        [-0.48],
#        [-0.46],
#        [-0.44],
#        [-0.42],
#        [-0.4 ],
#        [-0.38],
#        [-0.36],
#        [-0.34],
#        [-0.32],
#        [-0.3 ],
#        [-0.28],
#        [-0.26],
#        [-0.24],
#        [-0.22],
#        [-0.2 ],
#        [-0.18],
#        [-0.16],
#        [-0.14],
#        [-0.12],
#        [-0.1 ],
#        [-0.08],
#        [-0.06],
#        [-0.04],
#        [-0.02],
#        [ 0.  ],
#        [ 0.02],
#        [ 0.04],
#        [ 0.06],
#        [ 0.08],
#        [ 0.1 ],
#        [ 0.12],
#        [ 0.14],
#        [ 0.16],
#        [ 0.18],
#        [ 0.2 ],
#        [ 0.22],
#        [ 0.24],
#        [ 0.26],
#        [ 0.28],
#        [ 0.3 ],
#        [ 0.32],
#        [ 0.34],
#        [ 0.36],
#        [ 0.38],
#        [ 0.4 ],
#        [ 0.42],
#        [ 0.44],
#        [ 0.46],
#        [ 0.48],
#        [ 0.5 ],
#        [ 0.52],
#        [ 0.54],
#        [ 0.56],
#        [ 0.58],
#        [ 0.6 ],
#        [ 0.62],
#        [ 0.64],
#        [ 0.66],
#        [ 0.68],
#        [ 0.7 ],
#        [ 0.72],
#        [ 0.74],
#        [ 0.76],
#        [ 0.78],
#        [ 0.8 ],
#        [ 0.82],
#        [ 0.84],
#        [ 0.86],
#        [ 0.88],
#        [ 0.9 ],
#        [ 0.92],
#        [ 0.94],
#        [ 0.96],
#        [ 0.98],
#        [ 1.  ]])

# %%
model.score(X,Y)
# Out:
# 0.9212948050252968

# %%
model.predict(np.array(3))
# Out:
# array([[5.73144983]])

# %%
0.02409126*3+0.02409126
# Out:
# 0.09636504
